# %%
import numpy as np

input_size = 2
layers = [4,3]
output_size = 2

def softmax(a):
    e_pa = np.exp(a)
    ans= e_pa/np.sum(e_pa,axis=1,keepdims=True)
    return ans

class NeuralNetwork:
    def __init__(self,input_size,layers,output_size):
        np.random.seed(0)
        model={}
        model['W1'] = np.random.randn(input_size,layers[0])
        model['b1'] = np.zeros((1,layers[0]))
        
        model['W2'] = np.random.randn(layers[0],layers[1])
        model['b2'] = np.zeros((1,layers[1]))
        
        model['W3'] = np.random.randn(layers[1],output_size)
        model['b3'] = np.zeros((1,output_size))
        
        self.model = model
        
        
    def forward(self,x):
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        b1,b2,b3 = self.model['b1'],self.model['b2'],self.model['b3']
        
        z1 = np.dot(x,W1)+b1
        a1 = np.tanh(z1)
        
        z2 = np.dot(a1,W2)+b2
        a2 = np.tanh(z2)
        
        z3 = np.dot(a2,W3)+b3
        y_ = softmax(z3)
        
        self.activation_outputs = (a1,a2,y_)
        return y_
    
    def backward(self,x,y,learning_rate=0.01):
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        b1,b2,b3 = self.model['b1'],self.model['b2'],self.model['b3']
        m=x.shape[0]
        a1,a2,y_ = self.activation_outputs
        
        delta3 = y_ - y
        dw3 = np.dot(a2.T,delta3)
        db3 = np.sum(delta3,axis=0)/float(m)
        
        delta2 = (1-np.square(a2))*np.dot(delta3,W3.T)
        dw2=np.dot(a1.T,delta2)
        db2 = np.sum(delta2,axis=0)/float(m)
        
        delta1 = (1-np.square(a1))*np.dot(delta2,W2.T)
        dw1=np.dot(X.T,delta1)
        db1 = np.sum(delta1,axis=0)/float(m)
        
        #Update the MOdel Parameters using gradient descent
        self.model["W1"] -= learning_rate*dw1
        self.model["b1"] -= learning_rate*db1
        
        self.model["W2"] -= learning_rate*dw2
        self.model["b2"] -= learning_rate*db2
        
        self.model["W3"] -= learning_rate*dw3
        self.model["b3"] -= learning_rate*db3
        
    def predict(self,x):
        y_out = self.forward(x)
        return np.argmax(y_out,axis=1)
    
    def summary(self):
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        a1,a2,y_ = self.activation_outputs
        print("W1",W1.shape)
        print("A1",a1.shape)
        
        print("W2",W2.shape)
        print("A2",a2.shape)
        
        print("W3",W3.shape)
        print("Y_",y_.shape)
    
def loss(y_oht,p):
    l = -np.mean(y_oht*np.log(p))
    return l

def one_hot(y,depth):
    m=y.shape[0]
    y_hot = np.zeros((m,depth))
    y_hot[np.arange(m),y] = 1
    return y_hot

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
X,Y = make_circles(n_samples=500,shuffle=True,noise=0.05,random_state=1,factor=0.8)
plt.scatter(X[:,0],X[:,1],c=Y,cmap=plt.cm.Accent)
plt.show()

# %%
model = NeuralNetwork(input_size=2,layers=[10,5],output_size=2)

# %%
print(model.forward(X))
# Out:
# [[0.55194332 0.44805668]
#  [0.33167157 0.66832843]
#  [0.57653141 0.42346859]
#  [0.64245301 0.35754699]
#  [0.43752615 0.56247385]
#  [0.40112767 0.59887233]
#  [0.56280533 0.43719467]
#  [0.56481349 0.43518651]
#  [0.43108105 0.56891895]
#  [0.56552999 0.43447001]
#  [0.44043765 0.55956235]
#  [0.57381657 0.42618343]
#  [0.35938922 0.64061078]
#  [0.6890589  0.3109411 ]
#  [0.4451673  0.5548327 ]
#  [0.44192752 0.55807248]
#  [0.68271045 0.31728955]
#  [0.31706584 0.68293416]
#  [0.44391284 0.55608716]
#  [0.71891302 0.28108698]
#  [0.43764333 0.56235667]
#  [0.56236537 0.43763463]
#  [0.33650012 0.66349988]
#  [0.4384045  0.5615955 ]
#  [0.5796467  0.4203533 ]
#  [0.56840693 0.43159307]]

# %%
model.summary()
# Out:
# W1 (2, 10)
# A1 (500, 10)
# W2 (10, 5)
# A2 (500, 5)
# W3 (5, 2)
# Y_ (500, 2)

# %%
def train(X,Y,model,epochs,learning_rate,logs=True):
    training_loss=[]
    classes = 2
    Y_oht = one_hot(Y,classes)
    for ix in range(epochs):
        Y_ = model.forward(X)
        l = loss(Y_oht,Y_)
        model.backward(X,Y_oht,learning_rate)
        training_loss.append(l)
        if(logs):
            print("Epoch %d Loss %.4f"%(ix,l))
    return training_loss

# %%
loss=train(X,Y,model,500,0.001)
# Out:
# Epoch 0 Loss 0.3404
# Epoch 1 Loss 0.3404
# Epoch 2 Loss 0.3404
# Epoch 3 Loss 0.3403
# Epoch 4 Loss 0.3403
# Epoch 5 Loss 0.3403
# Epoch 6 Loss 0.3403
# Epoch 7 Loss 0.3402
# Epoch 8 Loss 0.3402
# Epoch 9 Loss 0.3402
# Epoch 10 Loss 0.3402
# Epoch 11 Loss 0.3402
# Epoch 12 Loss 0.3401
# Epoch 13 Loss 0.3401
# Epoch 14 Loss 0.3401
# Epoch 15 Loss 0.3401
# Epoch 16 Loss 0.3400
# Epoch 17 Loss 0.3400
# Epoch 18 Loss 0.3400
# Epoch 19 Loss 0.3400
# Epoch 20 Loss 0.3399
# Epoch 21 Loss 0.3399
# Epoch 22 Loss 0.3399
# Epoch 23 Loss 0.3399
# Epoch 24 Loss 0.3399
# Epoch 25 Loss 0.3398
# Epoch 26 Loss 0.3398
# Epoch 27 Loss 0.3398
# Epoch 28 Loss 0.3398
# Epoch 29 Loss 0.3397
# Epoch 30 Loss 0.3397
# Epoch 31 Loss 0.3397
# Epoch 32 Loss 0.3397
# Epoch 33 Loss 0.3396
# Epoch 34 Loss 0.3396
# Epoch 35 Loss 0.3396
# Epoch 36 Loss 0.3396
# Epoch 37 Loss 0.3395
# Epoch 38 Loss 0.3395
# Epoch 39 Loss 0.3395
# Epoch 40 Loss 0.3395
# Epoch 41 Loss 0.3395
# Epoch 42 Loss 0.3394
# Epoch 43 Loss 0.3394
# Epoch 44 Loss 0.3394
# Epoch 45 Loss 0.3394
# Epoch 46 Loss 0.3393
# Epoch 47 Loss 0.3393
# Epoch 48 Loss 0.3393
# Epoch 49 Loss 0.3393
# Epoch 50 Loss 0.3392
# Epoch 51 Loss 0.3392
# Epoch 52 Loss 0.3392
# Epoch 53 Loss 0.3392
# Epoch 54 Loss 0.3391
# Epoch 55 Loss 0.3391
# Epoch 56 Loss 0.3391
# Epoch 57 Loss 0.3391
# Epoch 58 Loss 0.3390
# Epoch 59 Loss 0.3390
# Epoch 60 Loss 0.3390
# Epoch 61 Loss 0.3390
# Epoch 62 Loss 0.3389
# Epoch 63 Loss 0.3389
# Epoch 64 Loss 0.3389
# Epoch 65 Loss 0.3389
# Epoch 66 Loss 0.3388
# Epoch 67 Loss 0.3388
# Epoch 68 Loss 0.3388
# Epoch 69 Loss 0.3388
# Epoch 70 Loss 0.3387
# Epoch 71 Loss 0.3387
# Epoch 72 Loss 0.3387
# Epoch 73 Loss 0.3387
# Epoch 74 Loss 0.3386
# Epoch 75 Loss 0.3386
# Epoch 76 Loss 0.3386
# Epoch 77 Loss 0.3386
# Epoch 78 Loss 0.3385
# Epoch 79 Loss 0.3385
# Epoch 80 Loss 0.3385
# Epoch 81 Loss 0.3385
# Epoch 82 Loss 0.3384
# Epoch 83 Loss 0.3384
# Epoch 84 Loss 0.3384
# Epoch 85 Loss 0.3384
# Epoch 86 Loss 0.3383
# Epoch 87 Loss 0.3383
# Epoch 88 Loss 0.3383
# Epoch 89 Loss 0.3383
# Epoch 90 Loss 0.3382
# Epoch 91 Loss 0.3382
# Epoch 92 Loss 0.3382
# Epoch 93 Loss 0.3382
# Epoch 94 Loss 0.3381
# Epoch 95 Loss 0.3381
# Epoch 96 Loss 0.3381
# Epoch 97 Loss 0.3381
# Epoch 98 Loss 0.3380
# Epoch 99 Loss 0.3380
# Epoch 100 Loss 0.3380
# Epoch 101 Loss 0.3380
# Epoch 102 Loss 0.3379
# Epoch 103 Loss 0.3379
# Epoch 104 Loss 0.3379
# Epoch 105 Loss 0.3380
# Epoch 106 Loss 0.3381
# Epoch 107 Loss 0.3386
# Epoch 108 Loss 0.3400
# Epoch 109 Loss 0.3438
# Epoch 110 Loss 0.3520
# Epoch 111 Loss 0.3698
# Epoch 112 Loss 0.3805
# Epoch 113 Loss 0.3903
# Epoch 114 Loss 0.3656
# Epoch 115 Loss 0.3597
# Epoch 116 Loss 0.3491
# Epoch 117 Loss 0.3461
# Epoch 118 Loss 0.3430
# Epoch 119 Loss 0.3418
# Epoch 120 Loss 0.3407
# Epoch 121 Loss 0.3401
# Epoch 122 Loss 0.3396
# Epoch 123 Loss 0.3394
# Epoch 124 Loss 0.3391
# Epoch 125 Loss 0.3390
# Epoch 126 Loss 0.3388
# Epoch 127 Loss 0.3388
# Epoch 128 Loss 0.3387
# Epoch 129 Loss 0.3387
# Epoch 130 Loss 0.3387
# Epoch 131 Loss 0.3387
# Epoch 132 Loss 0.3387
# Epoch 133 Loss 0.3389
# Epoch 134 Loss 0.3389
# Epoch 135 Loss 0.3391
# Epoch 136 Loss 0.3393
# Epoch 137 Loss 0.3397
# Epoch 138 Loss 0.3399
# Epoch 139 Loss 0.3405
# Epoch 140 Loss 0.3408
# Epoch 141 Loss 0.3416
# Epoch 142 Loss 0.3420
# Epoch 143 Loss 0.3429
# Epoch 144 Loss 0.3431
# Epoch 145 Loss 0.3440
# Epoch 146 Loss 0.3438
# Epoch 147 Loss 0.3444
# Epoch 148 Loss 0.3438
# Epoch 149 Loss 0.3440
# Epoch 150 Loss 0.3432
# Epoch 151 Loss 0.3431
# Epoch 152 Loss 0.3423
# Epoch 153 Loss 0.3422
# Epoch 154 Loss 0.3414
# Epoch 155 Loss 0.3413
# Epoch 156 Loss 0.3407
# Epoch 157 Loss 0.3406
# Epoch 158 Loss 0.3402
# Epoch 159 Loss 0.3401
# Epoch 160 Loss 0.3398
# Epoch 161 Loss 0.3398
# Epoch 162 Loss 0.3396
# Epoch 163 Loss 0.3396
# Epoch 164 Loss 0.3394
# Epoch 165 Loss 0.3395
# Epoch 166 Loss 0.3394
# Epoch 167 Loss 0.3394
# Epoch 168 Loss 0.3394
# Epoch 169 Loss 0.3395
# Epoch 170 Loss 0.3395
# Epoch 171 Loss 0.3396
# Epoch 172 Loss 0.3396
# Epoch 173 Loss 0.3398
# Epoch 174 Loss 0.3398
# Epoch 175 Loss 0.3401
# Epoch 176 Loss 0.3400
# Epoch 177 Loss 0.3403
# Epoch 178 Loss 0.3402
# Epoch 179 Loss 0.3405
# Epoch 180 Loss 0.3404
# Epoch 181 Loss 0.3407
# Epoch 182 Loss 0.3405
# Epoch 183 Loss 0.3408
# Epoch 184 Loss 0.3406
# Epoch 185 Loss 0.3407
# Epoch 186 Loss 0.3405
# Epoch 187 Loss 0.3406
# Epoch 188 Loss 0.3404
# Epoch 189 Loss 0.3405
# Epoch 190 Loss 0.3402
# Epoch 191 Loss 0.3403
# Epoch 192 Loss 0.3400
# Epoch 193 Loss 0.3401
# Epoch 194 Loss 0.3398
# Epoch 195 Loss 0.3399
# Epoch 196 Loss 0.3396
# Epoch 197 Loss 0.3397
# Epoch 198 Loss 0.3395
# Epoch 199 Loss 0.3396
# Epoch 200 Loss 0.3394
# Epoch 201 Loss 0.3395
# Epoch 202 Loss 0.3393
# Epoch 203 Loss 0.3394
# Epoch 204 Loss 0.3393
# Epoch 205 Loss 0.3394
# Epoch 206 Loss 0.3393
# Epoch 207 Loss 0.3394
# Epoch 208 Loss 0.3393
# Epoch 209 Loss 0.3394
# Epoch 210 Loss 0.3393
# Epoch 211 Loss 0.3395
# Epoch 212 Loss 0.3393
# Epoch 213 Loss 0.3395
# Epoch 214 Loss 0.3394
# Epoch 215 Loss 0.3395
# Epoch 216 Loss 0.3394
# Epoch 217 Loss 0.3395
# Epoch 218 Loss 0.3394
# Epoch 219 Loss 0.3395
# Epoch 220 Loss 0.3394
# Epoch 221 Loss 0.3395
# Epoch 222 Loss 0.3393
# Epoch 223 Loss 0.3395
# Epoch 224 Loss 0.3393
# Epoch 225 Loss 0.3394
# Epoch 226 Loss 0.3392
# Epoch 227 Loss 0.3393
# Epoch 228 Loss 0.3391
# Epoch 229 Loss 0.3392
# Epoch 230 Loss 0.3391
# Epoch 231 Loss 0.3392
# Epoch 232 Loss 0.3390
# Epoch 233 Loss 0.3391
# Epoch 234 Loss 0.3389
# Epoch 235 Loss 0.3390
# Epoch 236 Loss 0.3388
# Epoch 237 Loss 0.3390
# Epoch 238 Loss 0.3388
# Epoch 239 Loss 0.3389
# Epoch 240 Loss 0.3387
# Epoch 241 Loss 0.3389
# Epoch 242 Loss 0.3387
# Epoch 243 Loss 0.3388
# Epoch 244 Loss 0.3387
# Epoch 245 Loss 0.3388
# Epoch 246 Loss 0.3386
# Epoch 247 Loss 0.3388
# Epoch 248 Loss 0.3386
# Epoch 249 Loss 0.3387
# Epoch 250 Loss 0.3386
# Epoch 251 Loss 0.3387
# Epoch 252 Loss 0.3386
# Epoch 253 Loss 0.3387
# Epoch 254 Loss 0.3385
# Epoch 255 Loss 0.3387
# Epoch 256 Loss 0.3385
# Epoch 257 Loss 0.3386
# Epoch 258 Loss 0.3385
# Epoch 259 Loss 0.3386
# Epoch 260 Loss 0.3384
# Epoch 261 Loss 0.3385
# Epoch 262 Loss 0.3384
# Epoch 263 Loss 0.3385
# Epoch 264 Loss 0.3383
# Epoch 265 Loss 0.3384
# Epoch 266 Loss 0.3383
# Epoch 267 Loss 0.3384
# Epoch 268 Loss 0.3382
# Epoch 269 Loss 0.3383
# Epoch 270 Loss 0.3382
# Epoch 271 Loss 0.3383
# Epoch 272 Loss 0.3381
# Epoch 273 Loss 0.3382
# Epoch 274 Loss 0.3381
# Epoch 275 Loss 0.3382
# Epoch 276 Loss 0.3380
# Epoch 277 Loss 0.3381
# Epoch 278 Loss 0.3380
# Epoch 279 Loss 0.3381
# Epoch 280 Loss 0.3379
# Epoch 281 Loss 0.3380
# Epoch 282 Loss 0.3379
# Epoch 283 Loss 0.3380
# Epoch 284 Loss 0.3378
# Epoch 285 Loss 0.3379
# Epoch 286 Loss 0.3378
# Epoch 287 Loss 0.3379
# Epoch 288 Loss 0.3378
# Epoch 289 Loss 0.3379
# Epoch 290 Loss 0.3377
# Epoch 291 Loss 0.3378
# Epoch 292 Loss 0.3377
# Epoch 293 Loss 0.3378
# Epoch 294 Loss 0.3376
# Epoch 295 Loss 0.3377
# Epoch 296 Loss 0.3376
# Epoch 297 Loss 0.3377
# Epoch 298 Loss 0.3375
# Epoch 299 Loss 0.3376
# Epoch 300 Loss 0.3375
# Epoch 301 Loss 0.3376
# Epoch 302 Loss 0.3374
# Epoch 303 Loss 0.3375
# Epoch 304 Loss 0.3374
# Epoch 305 Loss 0.3375
# Epoch 306 Loss 0.3373
# Epoch 307 Loss 0.3374
# Epoch 308 Loss 0.3373
# Epoch 309 Loss 0.3374
# Epoch 310 Loss 0.3372
# Epoch 311 Loss 0.3373
# Epoch 312 Loss 0.3372
# Epoch 313 Loss 0.3373
# Epoch 314 Loss 0.3371
# Epoch 315 Loss 0.3372
# Epoch 316 Loss 0.3371
# Epoch 317 Loss 0.3372
# Epoch 318 Loss 0.3370
# Epoch 319 Loss 0.3371
# Epoch 320 Loss 0.3370
# Epoch 321 Loss 0.3371
# Epoch 322 Loss 0.3369
# Epoch 323 Loss 0.3370
# Epoch 324 Loss 0.3369
# Epoch 325 Loss 0.3370
# Epoch 326 Loss 0.3368
# Epoch 327 Loss 0.3369
# Epoch 328 Loss 0.3368
# Epoch 329 Loss 0.3369
# Epoch 330 Loss 0.3367
# Epoch 331 Loss 0.3368
# Epoch 332 Loss 0.3367
# Epoch 333 Loss 0.3368
# Epoch 334 Loss 0.3366
# Epoch 335 Loss 0.3367
# Epoch 336 Loss 0.3366
# Epoch 337 Loss 0.3367
# Epoch 338 Loss 0.3365
# Epoch 339 Loss 0.3366
# Epoch 340 Loss 0.3365
# Epoch 341 Loss 0.3366
# Epoch 342 Loss 0.3364
# Epoch 343 Loss 0.3365
# Epoch 344 Loss 0.3364
# Epoch 345 Loss 0.3365
# Epoch 346 Loss 0.3363
# Epoch 347 Loss 0.3364
# Epoch 348 Loss 0.3363
# Epoch 349 Loss 0.3364
# Epoch 350 Loss 0.3362
# Epoch 351 Loss 0.3363
# Epoch 352 Loss 0.3362
# Epoch 353 Loss 0.3362
# Epoch 354 Loss 0.3361
# Epoch 355 Loss 0.3362
# Epoch 356 Loss 0.3361
# Epoch 357 Loss 0.3361
# Epoch 358 Loss 0.3360
# Epoch 359 Loss 0.3361
# Epoch 360 Loss 0.3360
# Epoch 361 Loss 0.3360
# Epoch 362 Loss 0.3359
# Epoch 363 Loss 0.3360
# Epoch 364 Loss 0.3359
# Epoch 365 Loss 0.3359
# Epoch 366 Loss 0.3358
# Epoch 367 Loss 0.3359
# Epoch 368 Loss 0.3358
# Epoch 369 Loss 0.3358
# Epoch 370 Loss 0.3357
# Epoch 371 Loss 0.3358
# Epoch 372 Loss 0.3356
# Epoch 373 Loss 0.3357
# Epoch 374 Loss 0.3356
# Epoch 375 Loss 0.3356
# Epoch 376 Loss 0.3355
# Epoch 377 Loss 0.3356
# Epoch 378 Loss 0.3355
# Epoch 379 Loss 0.3355
# Epoch 380 Loss 0.3354
# Epoch 381 Loss 0.3355
# Epoch 382 Loss 0.3354
# Epoch 383 Loss 0.3354
# Epoch 384 Loss 0.3353
# Epoch 385 Loss 0.3354
# Epoch 386 Loss 0.3353
# Epoch 387 Loss 0.3353
# Epoch 388 Loss 0.3352
# Epoch 389 Loss 0.3353
# Epoch 390 Loss 0.3351
# Epoch 391 Loss 0.3352
# Epoch 392 Loss 0.3351
# Epoch 393 Loss 0.3351
# Epoch 394 Loss 0.3350
# Epoch 395 Loss 0.3351
# Epoch 396 Loss 0.3350
# Epoch 397 Loss 0.3350
# Epoch 398 Loss 0.3349
# Epoch 399 Loss 0.3350
# Epoch 400 Loss 0.3349
# Epoch 401 Loss 0.3349
# Epoch 402 Loss 0.3348
# Epoch 403 Loss 0.3349
# Epoch 404 Loss 0.3347
# Epoch 405 Loss 0.3348
# Epoch 406 Loss 0.3347
# Epoch 407 Loss 0.3347
# Epoch 408 Loss 0.3346
# Epoch 409 Loss 0.3347
# Epoch 410 Loss 0.3346
# Epoch 411 Loss 0.3346
# Epoch 412 Loss 0.3345
# Epoch 413 Loss 0.3346
# Epoch 414 Loss 0.3345
# Epoch 415 Loss 0.3345
# Epoch 416 Loss 0.3344
# Epoch 417 Loss 0.3344
# Epoch 418 Loss 0.3343
# Epoch 419 Loss 0.3344
# Epoch 420 Loss 0.3343
# Epoch 421 Loss 0.3343
# Epoch 422 Loss 0.3342
# Epoch 423 Loss 0.3343
# Epoch 424 Loss 0.3342
# Epoch 425 Loss 0.3342
# Epoch 426 Loss 0.3341
# Epoch 427 Loss 0.3341
# Epoch 428 Loss 0.3340
# Epoch 429 Loss 0.3341
# Epoch 430 Loss 0.3340
# Epoch 431 Loss 0.3340
# Epoch 432 Loss 0.3339
# Epoch 433 Loss 0.3339
# Epoch 434 Loss 0.3339
# Epoch 435 Loss 0.3339
# Epoch 436 Loss 0.3338
# Epoch 437 Loss 0.3338
# Epoch 438 Loss 0.3337
# Epoch 439 Loss 0.3338
# Epoch 440 Loss 0.3337
# Epoch 441 Loss 0.3337
# Epoch 442 Loss 0.3336
# Epoch 443 Loss 0.3336
# Epoch 444 Loss 0.3336
# Epoch 445 Loss 0.3336
# Epoch 446 Loss 0.3335
# Epoch 447 Loss 0.3335
# Epoch 448 Loss 0.3334
# Epoch 449 Loss 0.3334
# Epoch 450 Loss 0.3334
# Epoch 451 Loss 0.3334
# Epoch 452 Loss 0.3333
# Epoch 453 Loss 0.3333
# Epoch 454 Loss 0.3332
# Epoch 455 Loss 0.3333
# Epoch 456 Loss 0.3332
# Epoch 457 Loss 0.3332
# Epoch 458 Loss 0.3331
# Epoch 459 Loss 0.3331
# Epoch 460 Loss 0.3331
# Epoch 461 Loss 0.3331
# Epoch 462 Loss 0.3330
# Epoch 463 Loss 0.3330
# Epoch 464 Loss 0.3329
# Epoch 465 Loss 0.3329
# Epoch 466 Loss 0.3329
# Epoch 467 Loss 0.3329
# Epoch 468 Loss 0.3328
# Epoch 469 Loss 0.3328
# Epoch 470 Loss 0.3327
# Epoch 471 Loss 0.3327
# Epoch 472 Loss 0.3327
# Epoch 473 Loss 0.3327
# Epoch 474 Loss 0.3326
# Epoch 475 Loss 0.3326
# Epoch 476 Loss 0.3325
# Epoch 477 Loss 0.3325
# Epoch 478 Loss 0.3325
# Epoch 479 Loss 0.3325
# Epoch 480 Loss 0.3324
# Epoch 481 Loss 0.3324
# Epoch 482 Loss 0.3323
# Epoch 483 Loss 0.3323
# Epoch 484 Loss 0.3323
# Epoch 485 Loss 0.3323
# Epoch 486 Loss 0.3322
# Epoch 487 Loss 0.3322
# Epoch 488 Loss 0.3321
# Epoch 489 Loss 0.3321
# Epoch 490 Loss 0.3321
# Epoch 491 Loss 0.3321
# Epoch 492 Loss 0.3320
# Epoch 493 Loss 0.3320
# Epoch 494 Loss 0.3319
# Epoch 495 Loss 0.3319
# Epoch 496 Loss 0.3319
# Epoch 497 Loss 0.3319
# Epoch 498 Loss 0.3318
# Epoch 499 Loss 0.3318

# %%
plt.plot(loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
